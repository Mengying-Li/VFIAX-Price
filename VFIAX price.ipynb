# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('~/Downloads/HistoricalQuotes.csv')
df
# Out:
#             date     close        volume     open      high       low
# 0          16:00  274.2100     2,778,192  274.030  275.1900  273.4600
# 1     2019/07/10  274.2100  2853620.0000  274.020  275.1900  273.4600
# 2     2019/07/09  272.9400  2532925.0000  271.400  273.2200  271.3400
# 3     2019/07/08  272.6000  3131845.0000  272.790  273.0600  272.0300
# 4     2019/07/05  273.9700  3362535.0000  273.140  274.2500  271.8600
# 5     2019/07/03  274.3200  2335798.0000  272.910  274.3700  272.7600
# 6     2019/07/02  272.2300  3041654.0000  271.470  272.2500  270.6200
# 7     2019/07/01  271.4400  4505600.0000  272.460  272.6501  270.3000
# 8     2019/06/28  269.1500  2883271.0000  268.700  269.5500  268.1800
# 9     2019/06/27  267.6700  2054580.0000  267.490  268.1900  267.1702
# 10    2019/06/26  268.1200  2988721.0000  269.300  269.8200  268.0200
# 11    2019/06/25  268.3800  2287082.0000  271.100  271.1300  268.2700
# ...

# %%
# drop first row
df = df.iloc[1:]

# %%
# try buying at different date of month to see average price
# end with 01
print(df[df['date'].str.endswith('/01')]['close'].mean())
print(df[df['date'].str.endswith('/02')]['close'].mean())
print(df[df['date'].str.endswith('/03')]['close'].mean())
print(df[df['date'].str.endswith('/04')]['close'].mean())
print(df[df['date'].str.endswith('/05')]['close'].mean())
print(df[df['date'].str.endswith('/06')]['close'].mean())
print(df[df['date'].str.endswith('/07')]['close'].mean())
print(df[df['date'].str.endswith('/08')]['close'].mean())
print(df[df['date'].str.endswith('/09')]['close'].mean())
print(df[df['date'].str.endswith('/10')]['close'].mean())
print(df[df['date'].str.endswith('/11')]['close'].mean())
print(df[df['date'].str.endswith('/12')]['close'].mean())
print(df[df['date'].str.endswith('/13')]['close'].mean())
print(df[df['date'].str.endswith('/14')]['close'].mean())
print(df[df['date'].str.endswith('/15')]['close'].mean())
print(df[df['date'].str.endswith('/16')]['close'].mean())
print(df[df['date'].str.endswith('/17')]['close'].mean())
print(df[df['date'].str.endswith('/18')]['close'].mean())
print(df[df['date'].str.endswith('/19')]['close'].mean())
print(df[df['date'].str.endswith('/20')]['close'].mean())
print(df[df['date'].str.endswith('/21')]['close'].mean())
print(df[df['date'].str.endswith('/22')]['close'].mean())
print(df[df['date'].str.endswith('/23')]['close'].mean())
print(df[df['date'].str.endswith('/24')]['close'].mean())
print(df[df['date'].str.endswith('/25')]['close'].mean())
print(df[df['date'].str.endswith('/26')]['close'].mean())
print(df[df['date'].str.endswith('/27')]['close'].mean())
print(df[df['date'].str.endswith('/28')]['close'].mean())
print(df[df['date'].str.endswith('/29')]['close'].mean())
print(df[df['date'].str.endswith('/30')]['close'].mean())
print(df[df['date'].str.endswith('/31')]['close'].mean())
# Out:
# 180.43637681159427
# 181.85904225352118
# 180.57225352112673
# 179.14417647058823
# 182.92698630136985
# 182.36821333333336
# 180.22178933333328
# 181.54302368421057
# 180.1199600000001
# 180.52513026315785
# 179.92910526315794
# 182.22512533333324
# 180.89140259740253
# 179.25139473684217
# 178.77791891891889
# 179.72112676056335
# 180.90739726027402
# 180.99958333333325
# 180.7743083333333
# 182.21023918918922
# 180.59362432432428
# 180.86095890410962
# 178.76055068493153
# 181.1805527777778
# 180.44701492537314
# 183.4154507042254
# 180.74881216216218
# 180.03951351351364
# 179.77585294117648
# 180.48109375000007
# 181.60068181818184

# %%
# By Month
print(df[df['date'].str.contains('/01/')]['close'].mean())
print(df[df['date'].str.contains('/02/')]['close'].mean())
print(df[df['date'].str.contains('/03/')]['close'].mean())
print(df[df['date'].str.contains('/04/')]['close'].mean())
print(df[df['date'].str.contains('/05/')]['close'].mean())
print(df[df['date'].str.contains('/06/')]['close'].mean())
print(df[df['date'].str.contains('/07/')]['close'].mean())
print(df[df['date'].str.contains('/08/')]['close'].mean())
print(df[df['date'].str.contains('/09/')]['close'].mean())
print(df[df['date'].str.contains('/10/')]['close'].mean())
print(df[df['date'].str.contains('/11/')]['close'].mean())
print(df[df['date'].str.contains('/12/')]['close'].mean())
# Out:
# 178.6165907103825
# 180.8633190751445
# 184.08115641025648
# 185.7523838709678
# 187.2779834196891
# 187.80550366492153
# 184.7426857142857
# 180.82003798882684
# 173.75884157303378
# 174.02036548223347
# 175.38763675675676
# 175.55957393617024

# %%
# By Monday, Monday is 0 in number
df['day_of_week'] = pd.to_datetime(df['date']).dt.dayofweek
# Out:
# /Users/limengying/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df[:10]
# Out:
#           date   close        volume    open      high       low  day_of_week
# 1   2019/07/10  274.21  2853620.0000  274.02  275.1900  273.4600            2
# 2   2019/07/09  272.94  2532925.0000  271.40  273.2200  271.3400            1
# 3   2019/07/08  272.60  3131845.0000  272.79  273.0600  272.0300            0
# 4   2019/07/05  273.97  3362535.0000  273.14  274.2500  271.8600            4
# 5   2019/07/03  274.32  2335798.0000  272.91  274.3700  272.7600            2
# 6   2019/07/02  272.23  3041654.0000  271.47  272.2500  270.6200            1
# 7   2019/07/01  271.44  4505600.0000  272.46  272.6501  270.3000            0
# 8   2019/06/28  269.15  2883271.0000  268.70  269.5500  268.1800            4
# 9   2019/06/27  267.67  2054580.0000  267.49  268.1900  267.1702            3
# 10  2019/06/26  268.12  2988721.0000  269.30  269.8200  268.0200            2

# %%
print(df[df['day_of_week']==0]['close'].mean())
print(df[df['day_of_week']==1]['close'].mean())
print(df[df['day_of_week']==2]['close'].mean())
print(df[df['day_of_week']==3]['close'].mean())
print(df[df['day_of_week']==4]['close'].mean())
print(df[df['day_of_week']==5]['close'].mean())  # Saturday and Sunday market close
print(df[df['day_of_week']==6]['close'].mean())
# Out:
# 180.6737230215825
# 180.89279362637356
# 180.82948004385943
# 180.58084062500004
# 180.74181968680085
# nan
# nan
